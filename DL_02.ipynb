# %%
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 8 # Changed epochs to 8
w,b = np.zeros(2),0

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# error :  -1 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  1 <- at epoch 0
# [1. 1.] 0
# error :  -1 <- at epoch 1
# [1. 1.] -1
# error :  -1 <- at epoch 1
# [1. 0.] -2
# error :  0 <- at epoch 1
# [1. 0.] -2
# error :  1 <- at epoch 1
# [2. 1.] -1
# error :  0 <- at epoch 2
# [2. 1.] -1
# error :  -1 <- at epoch 2
# [2. 0.] -2
# error :  -1 <- at epoch 2
# [1. 0.] -3
# error :  1 <- at epoch 2
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  -1 <- at epoch 3
# [1. 1.] -3
# error :  1 <- at epoch 3
# [2. 2.] -2
# error :  0 <- at epoch 4
# [2. 2.] -2
# error :  -1 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 6
# [2. 1.] -3
# error :  0 <- at epoch 6
# [2. 1.] -3
# error :  0 <- at epoch 6
# [2. 1.] -3
# error :  0 <- at epoch 6
# [2. 1.] -3
# error :  0 <- at epoch 7
# [2. 1.] -3
# error :  0 <- at epoch 7
# [2. 1.] -3
# error :  0 <- at epoch 7
# [2. 1.] -3
# error :  0 <- at epoch 7
# [2. 1.] -3

# %%
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 10
w,b = [-3,5], 2 # Initialize weights and bias with random values

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# error :  -1 <- at epoch 0
# [-3  5] 1
# error :  -1 <- at epoch 0
# [-3  4] 0
# error :  0 <- at epoch 0
# [-3  4] 0
# error :  0 <- at epoch 0
# [-3  4] 0
# error :  -1 <- at epoch 1
# [-3  4] -1
# error :  -1 <- at epoch 1
# [-3  3] -2
# error :  0 <- at epoch 1
# [-3  3] -2
# error :  1 <- at epoch 1
# [-2  4] -1
# error :  0 <- at epoch 2
# [-2  4] -1
# error :  -1 <- at epoch 2
# [-2  3] -2
# error :  0 <- at epoch 2
# [-2  3] -2
# error :  1 <- at epoch 2
# [-1  4] -1
# error :  0 <- at epoch 3
# [-1  4] -1
# error :  -1 <- at epoch 3
# [-1  3] -2
# error :  0 <- at epoch 3
# [-1  3] -2
# error :  0 <- at epoch 3
# [-1  3] -2
# error :  0 <- at epoch 4
# [-1  3] -2
# error :  -1 <- at epoch 4
# [-1  2] -3
# error :  0 <- at epoch 4
# [-1  2] -3
# error :  1 <- at epoch 4
# [0 3] -2
# error :  0 <- at epoch 5
# [0 3] -2
# error :  -1 <- at epoch 5
# [0 2] -3
# error :  0 <- at epoch 5
# [0 2] -3
# error :  1 <- at epoch 5
# [1 3] -2
# error :  0 <- at epoch 6
# [1 3] -2
# error :  -1 <- at epoch 6
# [1 2] -3
# error :  0 <- at epoch 6
# [1 2] -3
# error :  0 <- at epoch 6
# [1 2] -3
# error :  0 <- at epoch 7
# [1 2] -3
# error :  0 <- at epoch 7
# [1 2] -3
# error :  0 <- at epoch 7
# [1 2] -3
# error :  0 <- at epoch 7
# [1 2] -3
# error :  0 <- at epoch 8
# [1 2] -3
# error :  0 <- at epoch 8
# [1 2] -3
# error :  0 <- at epoch 8
# [1 2] -3
# error :  0 <- at epoch 8
# [1 2] -3
# error :  0 <- at epoch 9
# [1 2] -3
# error :  0 <- at epoch 9
# [1 2] -3
# error :  0 <- at epoch 9
# [1 2] -3
# error :  0 <- at epoch 9
# [1 2] -3

# %%
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 8
w,b = [-3,5],2

for _ in range(epochs):
  total_error_in_epoch = 0 # Initialize total error for the current epoch
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    total_error_in_epoch += abs(E) # Accumulate absolute error
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
  if total_error_in_epoch == 0:
    print(f"Converged at epoch {_}. No errors found.")
    break # Stop training if no errors occurred in the epoch
# Out:
# error :  -1 <- at epoch 0
# [-3  5] 1
# error :  -1 <- at epoch 0
# [-3  4] 0
# error :  0 <- at epoch 0
# [-3  4] 0
# error :  0 <- at epoch 0
# [-3  4] 0
# error :  -1 <- at epoch 1
# [-3  4] -1
# error :  -1 <- at epoch 1
# [-3  3] -2
# error :  0 <- at epoch 1
# [-3  3] -2
# error :  1 <- at epoch 1
# [-2  4] -1
# error :  0 <- at epoch 2
# [-2  4] -1
# error :  -1 <- at epoch 2
# [-2  3] -2
# error :  0 <- at epoch 2
# [-2  3] -2
# error :  1 <- at epoch 2
# [-1  4] -1
# error :  0 <- at epoch 3
# [-1  4] -1
# error :  -1 <- at epoch 3
# [-1  3] -2
# error :  0 <- at epoch 3
# [-1  3] -2
# error :  0 <- at epoch 3
# [-1  3] -2
# error :  0 <- at epoch 4
# [-1  3] -2
# error :  -1 <- at epoch 4
# [-1  2] -3
# error :  0 <- at epoch 4
# [-1  2] -3
# error :  1 <- at epoch 4
# [0 3] -2
# error :  0 <- at epoch 5
# [0 3] -2
# error :  -1 <- at epoch 5
# [0 2] -3
# error :  0 <- at epoch 5
# [0 2] -3
# error :  1 <- at epoch 5
# [1 3] -2
# error :  0 <- at epoch 6
# [1 3] -2
# error :  -1 <- at epoch 6
# [1 2] -3
# error :  0 <- at epoch 6
# [1 2] -3
# error :  0 <- at epoch 6
# [1 2] -3
# error :  0 <- at epoch 7
# [1 2] -3
# error :  0 <- at epoch 7
# [1 2] -3
# error :  0 <- at epoch 7
# [1 2] -3
# error :  0 <- at epoch 7
# [1 2] -3
# Converged at epoch 7. No errors found.

# %%
import numpy as np
# for OR gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,1,1,1]) # Changed y_list for OR gate
epochs = 8
w,b =[-3,5],2

for _ in range(epochs):
  total_error_in_epoch = 0
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    total_error_in_epoch += abs(E)
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
  if total_error_in_epoch == 0:
    print(f"Converged at epoch {_}. No errors found.")
    break
# Out:
# error :  -1 <- at epoch 0
# [-3  5] 1
# error :  0 <- at epoch 0
# [-3  5] 1
# error :  1 <- at epoch 0
# [-2  5] 2
# error :  0 <- at epoch 0
# [-2  5] 2
# error :  -1 <- at epoch 1
# [-2  5] 1
# error :  0 <- at epoch 1
# [-2  5] 1
# error :  1 <- at epoch 1
# [-1  5] 2
# error :  0 <- at epoch 1
# [-1  5] 2
# error :  -1 <- at epoch 2
# [-1  5] 1
# error :  0 <- at epoch 2
# [-1  5] 1
# error :  0 <- at epoch 2
# [-1  5] 1
# error :  0 <- at epoch 2
# [-1  5] 1
# error :  -1 <- at epoch 3
# [-1  5] 0
# error :  0 <- at epoch 3
# [-1  5] 0
# error :  1 <- at epoch 3
# [0 5] 1
# error :  0 <- at epoch 3
# [0 5] 1
# error :  -1 <- at epoch 4
# [0 5] 0
# error :  0 <- at epoch 4
# [0 5] 0
# error :  0 <- at epoch 4
# [0 5] 0
# error :  0 <- at epoch 4
# [0 5] 0
# error :  -1 <- at epoch 5
# [0 5] -1
# error :  0 <- at epoch 5
# [0 5] -1
# error :  1 <- at epoch 5
# [1 5] 0
# error :  0 <- at epoch 5
# [1 5] 0
# error :  -1 <- at epoch 6
# [1 5] -1
# error :  0 <- at epoch 6
# [1 5] -1
# error :  0 <- at epoch 6
# [1 5] -1
# error :  0 <- at epoch 6
# [1 5] -1
# error :  0 <- at epoch 7
# [1 5] -1
# error :  0 <- at epoch 7
# [1 5] -1
# error :  0 <- at epoch 7
# [1 5] -1
# error :  0 <- at epoch 7
# [1 5] -1
# Converged at epoch 7. No errors found.

# %%
import numpy as np
# for XOR gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,1,1,0]) # Changed y_list for XOR gate
epochs = 8 # Increased epochs to clearly show non-convergence
w,b = [-3,5],2

for _ in range(epochs):
  total_error_in_epoch = 0
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    total_error_in_epoch += abs(E)
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
  if total_error_in_epoch == 0:
    print(f"Converged at epoch {_}. No errors found.")
    break
# Out:
# error :  -1 <- at epoch 0
# [-3  5] 1
# error :  0 <- at epoch 0
# [-3  5] 1
# error :  1 <- at epoch 0
# [-2  5] 2
# error :  -1 <- at epoch 0
# [-3  4] 1
# error :  -1 <- at epoch 1
# [-3  4] 0
# error :  0 <- at epoch 1
# [-3  4] 0
# error :  1 <- at epoch 1
# [-2  4] 1
# error :  -1 <- at epoch 1
# [-3  3] 0
# error :  -1 <- at epoch 2
# [-3  3] -1
# error :  0 <- at epoch 2
# [-3  3] -1
# error :  1 <- at epoch 2
# [-2  3] 0
# error :  -1 <- at epoch 2
# [-3  2] -1
# error :  0 <- at epoch 3
# [-3  2] -1
# error :  0 <- at epoch 3
# [-3  2] -1
# error :  1 <- at epoch 3
# [-2  2] 0
# error :  -1 <- at epoch 3
# [-3  1] -1
# error :  0 <- at epoch 4
# [-3  1] -1
# error :  0 <- at epoch 4
# [-3  1] -1
# error :  1 <- at epoch 4
# [-2  1] 0
# error :  0 <- at epoch 4
# [-2  1] 0
# error :  -1 <- at epoch 5
# [-2  1] -1
# error :  0 <- at epoch 5
# [-2  1] -1
# error :  1 <- at epoch 5
# [-1  1] 0
# error :  -1 <- at epoch 5
# [-2  0] -1
# error :  0 <- at epoch 6
# [-2  0] -1
# error :  1 <- at epoch 6
# [-2  1] 0
# error :  1 <- at epoch 6
# [-1  1] 1
# error :  -1 <- at epoch 6
# [-2  0] 0
# error :  -1 <- at epoch 7
# [-2  0] -1
# error :  1 <- at epoch 7
# [-2  1] 0
# error :  1 <- at epoch 7
# [-1  1] 1
# error :  -1 <- at epoch 7
# [-2  0] 0
